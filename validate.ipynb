# %%
import pandas as pd

# %%
df = pd.read_csv("./tires.csv")
df2 = pd.read_csv("./sample_test.csv")


df.head()
# Out:
#                                                  URL  \
# 0  https://www.pitstoparabia.com/en/kinergy-eco-k...
# 1  https://www.pitstoparabia.com/en/kinergy-eco-k...
# 2  https://www.pitstoparabia.com/en/n-blue-hd-plu...
# 3  https://www.pitstoparabia.com/en/thu-275-55r20...
# 4  https://www.pitstoparabia.com/en/roadmarch-507...
#
#                          sku                name attribute_set    type  \
# 0  161A0101557013TK425A-2021   Kinergy Eco K425        Default  Simple
# 1  161A0101656514K435XA-2021  Kinergy Eco2 K435        Default  Simple
# 2               NE-4268-2022     N Blue HD Plus        Default  Simple
# 3              MAT-9990-2022             Coloma        Default  Simple
# 4               RM-3346-2022          EcoPro 99        Default  Simple
#
#   categories                                        description  \
# 0  Car Tyres  SKU: 161A0101557013TK425A-2021 Kinergy Eco K42...
# 1  Car Tyres  SKU: 161A0101656514K435XA-2021 Kinergy Eco2 K4...
# ...

# %%
df.drop_duplicates()

# %%
df.nunique()
# Out:
# URL                        3731
# sku                        3638
# name                        457
# attribute_set                 2
# type                          2
# categories                    5
# description                3645
# short_description           457
# price                      1876
# qty                           2
# is_in_stock                   2
# manage_stock                  2
# use_config_manage_stock       2
# status                        2
# visibility                    2
# weight                        2
# tax_class_id                  2
# image_link                 3633
# image                      3633
# thumbnail                  3633
# small_image                3633
# manufacturer                 45
# country_of_manufacture       32
# sidewall                      5
# special_price              1197
# tyre_width                   23
# tyre_height                  17
# tyre_rim_size                18
# tyre_load                    84
# ...

# %%
len(df.values)
# Out:
# 4076
